# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Quickstart — Beer Game Behavioral Profiles\n",
    "Run a minimal simulation with random baseline agents."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from profiles_beergame.engine.simulation import SimulationRunner, SimulationConfig, constant_demand\n",
    "from profiles_beergame.agents.random_baseline import RandomBaselineAgent\n",
    "\n",
    "agents = {\n",
    "    'retailer': RandomBaselineAgent(3, 7, 1),\n",
    "    'wholesaler': RandomBaselineAgent(3, 7, 2),\n",
    "    'distributor': RandomBaselineAgent(3, 7, 3),\n",
    "    'factory': RandomBaselineAgent(3, 7, 4),\n",
    "}\n",
    "cfg = SimulationConfig(periods=20)\n",
    "runner = SimulationRunner(agents, demand_fn=constant_demand(4), config=cfg)\n",
    "df = runner.run()\n",
    "df.head()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
