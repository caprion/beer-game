# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Profiles Mixture Template\n",
    "Use this notebook to configure role-profile combinations and compare KPIs."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from profiles_beergame.engine.simulation import SimulationRunner, SimulationConfig, constant_demand\n",
    "from profiles_beergame.agents.random_baseline import RandomBaselineAgent\n",
    "import pandas as pd\n",
    "\n",
    "def run_scenario(seed_offset=0):\n",
    "    agents = {\n",
    "        'retailer': RandomBaselineAgent(2, 6, 10 + seed_offset),\n",
    "        'wholesaler': RandomBaselineAgent(2, 6, 20 + seed_offset),\n",
    "        'distributor': RandomBaselineAgent(2, 6, 30 + seed_offset),\n",
    "        'factory': RandomBaselineAgent(2, 6, 40 + seed_offset),\n",
    "    }\n",
    "    cfg = SimulationConfig(periods=50)\n",
    "    runner = SimulationRunner(agents, demand_fn=constant_demand(4), config=cfg)\n",
    "    return runner.run()\n",
    "\n",
    "df = run_scenario()\n",
    "df.tail()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
